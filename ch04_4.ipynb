# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/My Drive/ip/Images/girl.jpg')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(gImg1.shape)
cv2_imshow(gImg1)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
outlmg = np.zeros(gImg1.shape, dtype=np.uint8)

# %%
outlmg = cv2.equalizeHist(gImg)
cv2_imshow(outlmg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2628485115.py in <cell line: 0>()
# ----> 1 outlmg = cv2.equalizeHist(gImg)
#       2 cv2_imshow(outlmg)
#
# NameError: name 'gImg' is not defined

# %%
hist = cv2.calcHist([gImg1], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
myHist = np.zeros((256,1), dtype=np.int32)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    myHist[outImg1[h,w]] += 1

plt.plot(myHist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3313806245.py in <cell line: 0>()
#       1 for h in range(gImg1.shape[0]):
#       2   for w in range(gImg1.shape[1]):
# ----> 3     myHist[outImg1[h,w]] += 1
#       4
#       5 plt.plot(myHist)
#
# NameError: name 'outImg1' is not defined

# %%
cumulHist = np.zeros((256,1), dtype=np.int32)

# %%
cumulHist[0] = myHist[0]
for i in range(1,256):
  cumulHist[i] = cumulHist[i-1] + myHist[i]

plt.plot(cumulHist)

# %% [markdown]
# 히스토그램 평활화

# %%
equalHist = np.zeros((256,1), dtype=np.int32)

# %%
numOfPixel = gImg1.shape[0] + gImg1.shape[1]
equalHist = cumulHist / numOfPixel
equalHist = equalHist * 255

plt.plot(equalHist)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    outlmg[h,w] = equalHist[gImg1[h,w]]

cv2_imshow(outlmg)
# Out:
# /tmp/ipython-input-2866131323.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   outlmg[h,w] = equalHist[gImg1[h,w]]
# <PIL.Image.Image image mode=L size=256x256>
